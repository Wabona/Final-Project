# %% [markdown]
# ## Basic import statement

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import geopandas

arrest = pd.read_csv("arrests.csv")
arrest.sample(5)
# Out:
#             PK       CCR   AGE GENDER RACE           ARRESTTIME  \
# 37439  2022153  19248747  34.0      M    B  2019-12-07T11:30:00
# 14706  1993045  17214487  54.0      M    W  2017-11-05T21:54:00
# 27952  2009989  19016882  28.0      M    W  2019-01-26T20:26:00
# 44385  2031799  20191035  37.0      M    B  2020-10-12T18:57:00
# 18586  1998097  18030509  30.0      F    B  2018-03-22T18:35:00
#
#                                           ARRESTLOCATION  \
# 37439      Shetland ST & Lincoln AV Pittsburgh, PA 15206
# 14706                                             Zone 1
# 27952         Bates ST & I-376 RAMP Pittsburgh, PA 15213
# 44385  East Liberty BL & Larimer AV Pittsburgh, PA 15206
# 18586              900 Block 2nd AV Pittsburgh, PA 15219
#
#                                                 OFFENSES  \
# 37439  1785 Proof of Financial Responsibility Followi...
# 14706   2701 Simple Assault. / 2706 Terroristic Threats.
# 27952  1515 Notice of Change of Name or Address. / 17...
# 44385  1543 Driving While Operating Privilege is Susp...
# 18586  903 Criminal Conspiracy. / 2702 Aggravated Ass...
#
#                                         INCIDENTLOCATION INCIDENTNEIGHBORHOOD  \
# 37439       5th AV & S Dithridge ST Pittsburgh, PA 15213        North Oakland
# 14706                                             Zone 1                  NaN
# 27952         Bates ST & I-376 RAMP Pittsburgh, PA 15213        South Oakland
# 44385  East Liberty BL & Larimer AV Pittsburgh, PA 15206         East Liberty
# 18586          2100 Block Spring ST Pittsburgh, PA 15210            Arlington
#
#       INCIDENTZONE  INCIDENTTRACT  COUNCIL_DISTRICT  PUBLIC_WORKS_DIVISION  \
# 37439            4          404.0               8.0                    3.0
# 14706            1            NaN               NaN                    NaN
# 27952            4          409.0               NaN                    NaN
# 44385            5         1115.0               9.0                    2.0
# 18586            3         1603.0               3.0                    3.0
#
#                X          Y
# 37439 -79.950592  40.446808
# 14706        NaN        NaN
# 27952   0.000000   0.000000
# 44385 -79.917421  40.463436
# 18586 -79.977631  40.416927

# %% [markdown]
# ## Lists all the neighborhoods

# %%
towns = arrest["INCIDENTNEIGHBORHOOD"].unique()
print (towns)
# Out:
# ['Bloomfield' 'Outside City' 'Westwood' 'East Allegheny' 'Crafton Heights'
#  'Greenfield' 'Brookline' 'Regent Square' 'East Liberty' nan 'East Hills'
#  'Carrick' 'Allegheny Center' 'South Side Flats' 'Sheraden'
#  'East Carnegie' 'Golden Triangle/Civic Arena' 'Point Breeze North'
#  'Perry South' 'Allentown' 'North Shore' 'Marshall-Shadeland'
#  'Central Oakland' 'Middle Hill' 'Strip District'
#  'Lincoln-Lemington-Belmar' 'Central Northside' 'Troy Hill-Herrs Island'
#  'Highland Park' 'Homewood North' 'Northview Heights' 'Brighton Heights'
#  'Hazelwood' 'Perry North' 'Bedford Dwellings' 'Elliott' 'Beechview'
#  'Fineview' 'Glen Hazel' 'Spring Hill-City View' 'Bluff' 'Manchester'
#  'Homewood West' 'Outside County' 'Point Breeze' 'Homewood South'
#  'Squirrel Hill South' 'Terrace Village' 'Upper Lawrenceville' 'Arlington'
#  'South Side Slopes' 'Lower Lawrenceville' 'Garfield' 'Lincoln Place'
#  'Larimer' 'Mount Washington' 'California-Kirkbride' 'Banksville'
#  'Bon Air' 'South Shore' 'Beltzhoover' 'Knoxville' 'Chateau'
#  'Crawford-Roberts' 'Polish Hill' 'Fairywood' 'West End' 'Shadyside'
#  'Morningside' 'Overbrook' 'Friendship' 'North Oakland'
#  'Central Lawrenceville' 'Oakwood' 'Upper Hill' 'South Oakland'
#  'West Oakland' 'Spring Garden' 'Allegheny West' 'St. Clair'
#  'Stanton Heights' 'Esplen' 'Squirrel Hill North'
#  'Mt. Oliver Neighborhood' 'Summer Hill' 'Arlington Heights' 'Troy Hill'
#  'Central Business District' 'Central North Side' 'Mount Oliver' 'Windgap'
#  'Outside State' 'Duquesne Heights' 'New Homestead' 'Ridgemont'
#  'Swisshelm Park' 'Hays' 'Chartiers City' 'Mt. Oliver Boro']

# %% [markdown]
# ## Counts the number of arrests in each neighborhood

# %%
severity = arrest['OFFENSES'].str.contains('Harassment|Stalking|Homicide|Assault|Firearms|Missiles|Reckless Driving|Terroristic Threats|Kidnapping|Murder|Strangulation', regex = True).fillna(False)
crimes = arrest[severity]
crimes.sample(5)
# Out:
#             PK       CCR   AGE GENDER RACE           ARRESTTIME  \
# 33528  2017273  19071450  53.0      M    B  2019-08-12T14:25:00
# 25580  2007012  18171478  41.0      M    B  2018-11-05T13:00:00
# 33542  2017287  19154717  45.0      M    W  2019-08-05T17:00:00
# 27654  2009628  19002473  35.0      F    W  2019-01-21T13:40:00
# 48731  2038100  21093077  24.0      M    B  2021-05-27T23:00:00
#
#                                          ARRESTLOCATION  \
# 33528             200 Block 5th AV Pittsburgh, PA 15222
# 25580             900 Block 2nd AV Pittsburgh, PA 15219
# 33542       900 Block Brookline BL Pittsburgh, PA 15226
# 27654  1800 Block Spring Garden AV Pittsburgh, PA 15212
# 48731          800 Block Inwood ST Pittsburgh, PA 15208
#
#                                                 OFFENSES  \
# 33528  2706 Terroristic Threats. / 3304 Criminal Misc...
# 25580  907 Possessing Instruments of Crime. / 2701 Si...
# 33542                               2701 Simple Assault.
# 27654  2701 Simple Assault. / 3304 Criminal Mischief....
# 48731  3925 Receiving Stolen Property. / 6106 Firearm...
#
#                                        INCIDENTLOCATION INCIDENTNEIGHBORHOOD  \
# 33528  Allegheny AV & Reedsdale ST Pittsburgh, PA 15233              Chateau
# 25580            500 Block 52nd ST Pittsburgh, PA 15201  Upper Lawrenceville
# 33542       900 Block Brookline BL Pittsburgh, PA 15226            Brookline
# 27654  1800 Block Spring Garden AV Pittsburgh, PA 15212        Spring Garden
# 48731          800 Block Inwood ST Pittsburgh, PA 15208        Homewood West
#
#       INCIDENTZONE  INCIDENTTRACT  COUNCIL_DISTRICT  PUBLIC_WORKS_DIVISION  \
# 33528            1         2108.0               6.0                    1.0
# 25580            2         1011.0               7.0                    2.0
# 33542            6         1919.0               4.0                    5.0
# 27654            1         2412.0               1.0                    1.0
# 48731            5         1207.0               9.0                    2.0
#
#                X          Y
# 33528 -80.019201  40.452373
# 25580 -79.952866  40.479291
# 33542 -80.019190  40.392879
# 27654 -79.985244  40.467430
# 48731 -79.904981  40.458183

# %% [markdown]
# ## Graphs data

# %%
arrestNeighborhood=crimes["INCIDENTNEIGHBORHOOD"]
#arrestNeighborhood.sort_values(ascending = False).plot.bar(figsize=(20,11))
arrestNeighborhood
# Out:
# 4        Crafton Heights
# 6              Brookline
# 7          Regent Square
# 10            East Hills
# 11               Carrick
#               ...
# 54473     Homewood South
# 54475          Knoxville
# 54477                NaN
# 54478      North Oakland
# 54479      Homewood West
# Name: INCIDENTNEIGHBORHOOD, Length: 19796, dtype: object

# %%
neighborhoods = geopandas.read_file("Neighborhoods/Neighborhoods_.shp") # read in the shapefile
#neighborhoods.plot(figsize=(20,11)) # plot the geopandas dataframe# do the merge
crime_map = neighborhoods.merge(arrestNeighborhood, how='left', left_on='hood', right_on="INCIDENTNEIGHBORHOOD")
# look at the head to confirm it merged correctly
crime_map
#crime_map.plot(column='number_of_steps')
# Out:
#        objectid  fid_blockg statefp10 countyfp10 tractce10 blkgrpce10  \
# 0             1         0.0        42        003    040500          1
# 1             1         0.0        42        003    040500          1
# 2             1         0.0        42        003    040500          1
# 3             1         0.0        42        003    040500          1
# 4             1         0.0        42        003    040500          1
# ...         ...         ...       ...        ...       ...        ...
# 18629      1292         NaN      None       None      None       None
# 18630      1292         NaN      None       None      None       None
# 18631      1292         NaN      None       None      None       None
# 18632      1292         NaN      None       None      None       None
# 18633      1292         NaN      None       None      None       None
#
#             geoid10     namelsad10 mtfcc10 funcstat10  ...  page_numbe  \
# 0      420030405001  Block Group 1   G5030          S  ...          15
# 1      420030405001  Block Group 1   G5030          S  ...          15
# 2      420030405001  Block Group 1   G5030          S  ...          15
# 3      420030405001  Block Group 1   G5030          S  ...          15
# 4      420030405001  Block Group 1   G5030          S  ...          15
# ...             ...            ...     ...        ...  ...         ...
# 18629          None           None    None       None  ...          15
# 18630          None           None    None       None  ...          15
# 18631          None           None    None       None  ...          15
# 18632          None           None    None       None  ...          15
# 18633          None           None    None       None  ...          15
#
#                   plannerass created_us                created_da  last_edite  \
# 0              Derek Dauphin  pgh.admin  2019-10-23T14:17:16.403Z   pgh.admin
# 1              Derek Dauphin  pgh.admin  2019-10-23T14:17:16.403Z   pgh.admin
# 2              Derek Dauphin  pgh.admin  2019-10-23T14:17:16.403Z   pgh.admin
# 3              Derek Dauphin  pgh.admin  2019-10-23T14:17:16.403Z   pgh.admin
# 4              Derek Dauphin  pgh.admin  2019-10-23T14:17:16.403Z   pgh.admin
# ...                      ...        ...                       ...         ...
# 18629  Stephanie Joy Everett  pgh.admin  2019-10-23T14:17:16.403Z   pgh.admin
# 18630  Stephanie Joy Everett  pgh.admin  2019-10-23T14:17:16.403Z   pgh.admin
# 18631  Stephanie Joy Everett  pgh.admin  2019-10-23T14:17:16.403Z   pgh.admin
# 18632  Stephanie Joy Everett  pgh.admin  2019-10-23T14:17:16.403Z   pgh.admin
# 18633  Stephanie Joy Everett  pgh.admin  2019-10-23T14:17:16.403Z   pgh.admin
#
#                      last_edi_1    Shape__Are    Shape__Len  \
# 0      2019-10-23T14:17:16.403Z  7.842997e+06  11525.904546
# 1      2019-10-23T14:17:16.403Z  7.842997e+06  11525.904546
# 2      2019-10-23T14:17:16.403Z  7.842997e+06  11525.904546
# 3      2019-10-23T14:17:16.403Z  7.842997e+06  11525.904546
# 4      2019-10-23T14:17:16.403Z  7.842997e+06  11525.904546
# ...                         ...           ...           ...
# 18629  2019-10-23T14:17:16.403Z  3.461777e+07  31328.878632
# 18630  2019-10-23T14:17:16.403Z  3.461777e+07  31328.878632
# 18631  2019-10-23T14:17:16.403Z  3.461777e+07  31328.878632
# 18632  2019-10-23T14:17:16.403Z  3.461777e+07  31328.878632
# 18633  2019-10-23T14:17:16.403Z  3.461777e+07  31328.878632
#
#                                                 geometry  INCIDENTNEIGHBORHOOD
# 0      POLYGON ((-79.95304 40.44203, -79.95302 40.442...       Central Oakland
# 1      POLYGON ((-79.95304 40.44203, -79.95302 40.442...       Central Oakland
# 2      POLYGON ((-79.95304 40.44203, -79.95302 40.442...       Central Oakland
# 3      POLYGON ((-79.95304 40.44203, -79.95302 40.442...       Central Oakland
# 4      POLYGON ((-79.95304 40.44203, -79.95302 40.442...       Central Oakland
# ...                                                  ...                   ...
# 18629  POLYGON ((-80.01783 40.49736, -80.01787 40.497...           Perry North
# 18630  POLYGON ((-80.01783 40.49736, -80.01787 40.497...           Perry North
# 18631  POLYGON ((-80.01783 40.49736, -80.01787 40.497...           Perry North
# 18632  POLYGON ((-80.01783 40.49736, -80.01787 40.497...           Perry North
# 18633  POLYGON ((-80.01783 40.49736, -80.01787 40.497...           Perry North
#
# [18634 rows x 39 columns]
