# %% [markdown]
# # Crime Rate

# %% [markdown]
# ### Basic import statement

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import geopandas

arrest = pd.read_csv("arrests.csv")
arrest.sample(5)
# Out:
#             PK       CCR   AGE GENDER RACE           ARRESTTIME  \
# 18408  1997874  18046130  24.0      F    B  2018-03-12T01:35:00
# 11742  1989259  17152500  38.0      M    W  2017-08-12T18:19:00
# 43052  2030105  20153057  37.0      F    W  2020-08-18T16:29:00
# 26454  2008124  18235623  33.0      M    W  2018-12-12T09:30:00
# 39713  2025184  20021426  15.0      M    B  2020-01-31T15:00:00
#
#                                      ARRESTLOCATION  \
# 18408     100 Block Penfort ST Pittsburgh, PA 15214
# 11742  300 Block Birmingham AV Pittsburgh, PA 15210
# 43052       Raven ST & Becks Run RD Pittsburgh, PA
# 26454         900 Block 2ND AV Pittsburgh, PA 15219
# 39713         600 Block 1ST AV PITTSBURGH, PA 15219
#
#                                                 OFFENSES  \
# 18408                               2701 Simple Assault.
# 11742  2701 Simple Assault. / 13(a)(32) Paraphernalia...
# 43052        13(a)(32) Paraphernalia - Use or Possession
# 26454                    3925 Receiving Stolen Property.
# 39713  2702 Aggravated Assault. / 5503(a)(4) DISORDER...
#
#                                     INCIDENTLOCATION INCIDENTNEIGHBORHOOD  \
# 18408      100 Block Penfort ST Pittsburgh, PA 15214    Northview Heights
# 11742   300 Block Birmingham AV Pittsburgh, PA 15210              Carrick
# 43052        Raven ST & Becks Run RD Pittsburgh, PA               Carrick
# 26454       100 Block S 15th ST Pittsburgh, PA 15203     South Side Flats
# 39713  1100 Block N MURTLAND ST PITTSBURGH, PA 15208        Homewood West
#
#       INCIDENTZONE  INCIDENTTRACT  COUNCIL_DISTRICT  PUBLIC_WORKS_DIVISION  \
# 18408            1         2609.0               1.0                    1.0
# 11742            3         2902.0               4.0                    3.0
# 43052            3         2904.0               4.0                    3.0
# 26454            3         1702.0               3.0                    3.0
# 39713            5         1207.0               9.0                    2.0
#
#                X          Y
# 18408 -80.002822  40.473350
# 11742 -79.984019  40.402793
# 43052 -79.981854  40.391061
# 26454 -79.983474  40.427953
# 39713 -79.900145  40.460419

# %% [markdown]
# ### Lists all the neighborhoods

# %%
towns = arrest["INCIDENTNEIGHBORHOOD"].unique()
print (towns)
# Out:
# ['Bloomfield' 'Outside City' 'Westwood' 'East Allegheny' 'Crafton Heights'
#  'Greenfield' 'Brookline' 'Regent Square' 'East Liberty' nan 'East Hills'
#  'Carrick' 'Allegheny Center' 'South Side Flats' 'Sheraden'
#  'East Carnegie' 'Golden Triangle/Civic Arena' 'Point Breeze North'
#  'Perry South' 'Allentown' 'North Shore' 'Marshall-Shadeland'
#  'Central Oakland' 'Middle Hill' 'Strip District'
#  'Lincoln-Lemington-Belmar' 'Central Northside' 'Troy Hill-Herrs Island'
#  'Highland Park' 'Homewood North' 'Northview Heights' 'Brighton Heights'
#  'Hazelwood' 'Perry North' 'Bedford Dwellings' 'Elliott' 'Beechview'
#  'Fineview' 'Glen Hazel' 'Spring Hill-City View' 'Bluff' 'Manchester'
#  'Homewood West' 'Outside County' 'Point Breeze' 'Homewood South'
#  'Squirrel Hill South' 'Terrace Village' 'Upper Lawrenceville' 'Arlington'
#  'South Side Slopes' 'Lower Lawrenceville' 'Garfield' 'Lincoln Place'
#  'Larimer' 'Mount Washington' 'California-Kirkbride' 'Banksville'
#  'Bon Air' 'South Shore' 'Beltzhoover' 'Knoxville' 'Chateau'
#  'Crawford-Roberts' 'Polish Hill' 'Fairywood' 'West End' 'Shadyside'
#  'Morningside' 'Overbrook' 'Friendship' 'North Oakland'
#  'Central Lawrenceville' 'Oakwood' 'Upper Hill' 'South Oakland'
#  'West Oakland' 'Spring Garden' 'Allegheny West' 'St. Clair'
#  'Stanton Heights' 'Esplen' 'Squirrel Hill North'
#  'Mt. Oliver Neighborhood' 'Summer Hill' 'Arlington Heights' 'Troy Hill'
#  'Central Business District' 'Central North Side' 'Mount Oliver' 'Windgap'
#  'Outside State' 'Duquesne Heights' 'New Homestead' 'Ridgemont'
#  'Swisshelm Park' 'Hays' 'Chartiers City' 'Mt. Oliver Boro']

# %% [markdown]
# ### Counts the number of fatal/life-threatening arrests in each neighborhood
# * Harassment, stalking, homicide, assault, misuse of firearms, reckless driving, terroristic threats, kidnapping, murder, strangulation, and missiles

# %%
severity = arrest['OFFENSES'].str.contains('Harassment|Stalking|Homicide|Assault|Firearms|Reckless Driving|Terroristic Threats|Kidnapping|Murder|Strangulation|Missiles|', regex = True).fillna(False)
crimes = arrest[severity]
crimes.sample(5)
# Out:
#             PK       CCR   AGE GENDER RACE           ARRESTTIME  \
# 25584  2007016  18175580  37.0      M    B  2018-11-02T21:58:00
# 6066   1982167  17036678  26.0      M    B  2017-02-28T01:00:00
# 14248  1992486  17206323  43.0      M    B  2017-10-25T14:00:00
# 9476   1986545  17110336  57.0      M    B  2017-06-17T18:53:00
# 24973  2006233  18191247  15.0      M    B  2018-10-01T11:40:00
#
#                                        ARRESTLOCATION  \
# 25584       100 Block Hazlett ST Pittsburgh, PA 15214
# 6066            600 Block 1st AV Pittsburgh, PA 15219
# 14248       3800 Block O'Hara ST Pittsburgh, PA 15213
# 9476   Federal ST N & E North AV Pittsburgh, PA 15212
# 24973           600 Block 1ST AV PITTSBURGH, PA 15219
#
#                                                 OFFENSES  \
# 25584                               2701 Simple Assault.
# 6066   3304 Criminal Mischief. / 2709(a)(1) Harassmen...
# 14248                          2706 Terroristic Threats.
# 9476   2701 Simple Assault. / 3921(a) Theft by Unlawf...
# 24973  2701 Simple Assault. / 5501 Riot. / 5503 Disor...
#
#                                     INCIDENTLOCATION   INCIDENTNEIGHBORHOOD  \
# 25584  800 Block Mt Pleasant RD Pittsburgh, PA 15214      Northview Heights
# 6066         100 Block Rhine PL Pittsburgh, PA 15212  Spring Hill-City View
# 14248      3800 Block O'Hara ST Pittsburgh, PA 15213        Central Oakland
# 9476    1000 Block Sheffield ST Pittsburgh, PA 15233             Manchester
# 24973      3100 Block CENTRE AV PITTSBURGH, PA 15219             Upper Hill
#
#       INCIDENTZONE  INCIDENTTRACT  COUNCIL_DISTRICT  PUBLIC_WORKS_DIVISION  \
# 25584            1         2609.0               1.0                    1.0
# 6066             1         2620.0               1.0                    1.0
# 14248            4          405.0               8.0                    3.0
# 9476             1         2107.0               6.0                    1.0
# 24973            2          506.0               6.0                    3.0
#
#                X          Y
# 25584 -79.999476  40.475752
# 6066  -79.994099  40.466786
# 14248 -79.959560  40.443316
# 9476  -80.019796  40.454103
# 24973 -79.962021  40.448843

# %% [markdown]
# ### Graphs data

# %%
arrestNeighborhood=crimes["INCIDENTNEIGHBORHOOD"]
arrestNeighborhood.value_counts().sort_values(ascending = False).plot.bar(figsize=(20,11))

# %% [markdown]
# The highest overall arrest data was in the Central Business District but when

# %%
neighborhoods = geopandas.read_file("Neighborhoods/Neighborhoods_.shp") # read in the shapefile
#neighborhoods.plot(figsize=(20,11)) # plot the geopandas dataframe# do the merge
crime_map = neighborhoods.merge(arrestNeighborhood, how='left', left_on='hood', right_on="INCIDENTNEIGHBORHOOD")
crime_map
#crime_map.plot(column='number_of_steps')
