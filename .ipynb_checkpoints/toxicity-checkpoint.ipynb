# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

toxin = pd.read_csv("toxin.csv")
toxin.head()
# Out:
#    TRI_FACILITY_ID   DOC_CTRL_NUM                             FACILITY_NAME  \
# 0  15226MTTHW1315W  1396105260741               MATTHEWS INTERNATIONAL CORP
# 1  15025RSTCH400ST  1388025294164            KOPPERS INC CLAIRTON TAR PLANT
# 2  15144PPGND125CO  1310208167751      PPG INDUSTRIESINC-SPRINGDALE COMPLEX
# 3  15139TRNGL931TH  1389035450600                      GLOBAL CIRCUITS INC.
# 4  15020SNCCHBUNOL  1302200503023  UNIVAR SOLUTIONS USA INC - BUNOLA BRANCH
#
#         STREET_ADDRESS   CITY_NAME COUNTY_NAME  STATE_COUNTY_FIPS_CODE  \
# 0   1315 W LIBERTY AVE  PITTSBURGH   ALLEGHENY                   42003
# 1       300 N STATE ST    CLAIRTON   ALLEGHENY                   42003
# 2        125 COLFAX ST  SPRINGDALE   ALLEGHENY                   42003
# 3           931 3RD ST     OAKMONT   ALLEGHENY                   42003
# 4  328 BUNOLA RIVER RD      BUNOLA   ALLEGHENY                   42003
#
#   STATE_ABBR  ZIP_CODE  REGION  ...  RELEASE_RANGE_CODE TOTAL_RELEASE  \
# 0         PA     15226       3  ...                 NaN           NaN
# 1         PA     15025       3  ...                 NaN           0.0
# 2         PA     15144       3  ...                 NaN           NaN
# 3         PA     15139       3  ...                 NaN           NaN
# 4         PA     15020       3  ...                 NaN           NaN
#
#   REL_EST_AMT RELEASE_NA RELEASE_BASIS_EST_CODE WATER_SEQUENCE_NUM  \
# 0         0.0          0                    NaN                  1
# 1         0.0          0                      O                  1
# 2         0.0          1                    NaN                  1
# 3         0.0          1                    NaN                  1
# 4         0.0          0                    NaN                  1
#
#     STREAM_NAME  STORM_WATER_NA  STORM_WATER_PERCENT REACH_CODE
# 0           NaN               0                  NaN        NaN
# 1  PETERS CREEK               0                  NaN        NaN
# 2           NaN               0                  NaN        NaN
# 3           NaN               1                  NaN        NaN
# 4           NaN               0                  NaN        NaN
#
# [5 rows x 43 columns]

# %%
cities = toxin['CITY_NAME'] == "PITTSBURGH"
pittsburgh = toxin[cities]
pittsburgh
# Out:
#        TRI_FACILITY_ID   DOC_CTRL_NUM  \
# 0      15226MTTHW1315W  1396105260741
# 8      15233THVLS2000W  1393070296494
# 20     15201XXNCM34THS  1393075550259
# 21     15225CLGNC200NE  1300140375647
# 23     15225WTSNSCORNE  1316215159841
# ...                ...            ...
# 15176  15225SHLND2650N  1312210467407
# 15178  15238CHSCR128FI  1391055000133
# 15181  15225SHLND2650N  1310208527628
# 15196  15275SHNDN171IN  1394085460071
# 15199  15201MCCNW10948  1309207251897
#
#                                    FACILITY_NAME      STREET_ADDRESS  \
# 0                    MATTHEWS INTERNATIONAL CORP  1315 W LIBERTY AVE
# 8                            SHERWIN-WILLIAMS CO    2000 WESTHALL ST
# 20                 EXXON CO USA PITTSBURGH PLANT         100 35TH ST
# 21       CALGON CARBON CORP NEVILLE ISLAND PLANT      200 NEVILLE RD
# 23     WATSON STANDARD CO (NEVILLE ISLAND PLANT)      2895 GRAND AVE
# ...                                          ...                 ...
# 15176                    INEOS COMPOSITES US LLC     2650 NEVILLE RD
# 15178                      CHASE CORP-PITTSBURGH        128 FIRST ST
# 15181                    INEOS COMPOSITES US LLC     2650 NEVILLE RD
# 15196                   THERMO FISHER SCIENTIFIC     171 INDUSTRY DR
# 15199             MCCONWAY & TORLEY LLC PLT 1801         109 48TH ST
#
#         CITY_NAME COUNTY_NAME  STATE_COUNTY_FIPS_CODE STATE_ABBR  ZIP_CODE  \
# 0      PITTSBURGH   ALLEGHENY                   42003         PA     15226
# 8      PITTSBURGH   ALLEGHENY                   42003         PA     15233
# 20     PITTSBURGH   ALLEGHENY                   42003         PA     15201
# 21     PITTSBURGH   ALLEGHENY                   42003         PA     15225
# 23     PITTSBURGH   ALLEGHENY                   42003         PA     15225
# ...           ...         ...                     ...        ...       ...
# 15176  PITTSBURGH   ALLEGHENY                   42003         PA     15225
# 15178  PITTSBURGH   ALLEGHENY                   42003         PA     15238
# 15181  PITTSBURGH   ALLEGHENY                   42003         PA     15225
# 15196  PITTSBURGH   ALLEGHENY                   42003         PA     15275
# 15199  PITTSBURGH   ALLEGHENY                   42003         PA     15201
#
#        REGION  ...  RELEASE_RANGE_CODE TOTAL_RELEASE REL_EST_AMT RELEASE_NA  \
# 0           3  ...                 NaN           NaN         0.0          0
# 8           3  ...                 NaN           NaN         0.0          1
# 20          3  ...                 NaN           0.0         0.0          0
# 21          3  ...                 NaN           NaN         0.0          0
# 23          3  ...                 NaN           NaN         0.0          1
# ...       ...  ...                 ...           ...         ...        ...
# 15176       3  ...                 NaN           NaN         0.0          1
# 15178       3  ...                 NaN           NaN         0.0          0
# 15181       3  ...                 NaN           NaN         0.0          1
# 15196       3  ...                 NaN           0.0         0.0          0
# 15199       3  ...                 NaN           NaN         0.0          1
#
#       RELEASE_BASIS_EST_CODE WATER_SEQUENCE_NUM      STREAM_NAME  \
# 0                        NaN                  1              NaN
# 8                        NaN                  1              NaN
# 20                         M                  1  ALLEGHENY RIVER
# 21                       NaN                  1              NaN
# 23                       NaN                  1              NaN
# ...                      ...                ...              ...
# 15176                    NaN                  1              NaN
# 15178                    NaN                  2              NaN
# 15181                    NaN                  1              NaN
# 15196                      O                  1                0
# 15199                    NaN                  1              NaN
#
#        STORM_WATER_NA  STORM_WATER_PERCENT REACH_CODE
# 0                   0                  NaN        NaN
# 8                   1                  NaN        NaN
# 20                  0                100.0        NaN
# 21                  0                  NaN        NaN
# 23                  0                  NaN        NaN
# ...               ...                  ...        ...
# 15176               0                  NaN        NaN
# 15178               0                  NaN        NaN
# 15181               0                  NaN        NaN
# 15196               0                  NaN        NaN
# 15199               0                  NaN        NaN
#
# [4862 rows x 43 columns]
